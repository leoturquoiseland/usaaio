# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
np.random.seed(33550336)

# %%
from scipy.stats import expon

# %%
mu = 1
sigma = 1

# %%
sam = expon.rvs(scale = 1, size = 100000)

# %%
np.sum(sam > 3) / len(sam)
# Out:
# np.float64(0.05089)

# %%
from scipy.stats import uniform

# %%
n = 100
t = 0.1

# %%
sam = uniform.rvs(loc = 0, scale = 1, size = 10000)

# %%
np.sum(np.abs(sam - 0.5) >= 0.1) / len(sam)
# Out:
# np.float64(0.796)
