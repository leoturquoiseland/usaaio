# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
np.random.seed(33550336)

# %%
dat = np.random.normal(loc = 5, scale = 2, size = 100000)

# %%
n = len(dat)

# %%
mh = np.sum(dat)/n

# %%
shat = np.sum((dat- mh) ** 2) / n

# %%
shat
# Out:
# np.float64(3.9979513529074913)

# %%
mh
# Out:
# np.float64(5.005362042584297)

# %%
np.var(dat, ddof=0)
# Out:
# np.float64(3.9979513529074913)

# %%
np.mean(dat)
# Out:
# np.float64(5.005362042584297)

# %%
dat = np.random.poisson(lam = 3, size = 100000)

# %%
lamhat = np.mean(dat)

# %%
lamhat
# Out:
# np.float64(3.00998)

# %%
n = 1000

# %%
dat = np.random.normal(loc=5, scale=2, size=n)

# %%
mu0 = 0 
scale1 = 1

# %%
n = len(dat)

# %%
mle = np.mean(dat)

# %%
umap = (4 * mu0   + n * scale1 * mle)/(4 + n * scale1)

# %%
umap
# Out:
# np.float64(4.9657048774856305)

# %%
mle
# Out:
# np.float64(4.985567696995573)

# %%
from scipy.stats import beta

# %%
x = np.linspace(0, 1, 500)

# %%
likelihood = x**7 * (1 - x)**3

# %%
plt.plot(x, beta.pdf(x, a = 2, b = 2))
plt.plot(x, beta.pdf(x, a = 9, b = 5))
plt.plot(x, beta.pdf(x, a = 8, b = 4))
