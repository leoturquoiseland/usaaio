# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
def f(x, y):
    return x ** 2 + 2 * y ** 2

# %%
hes = np.array([[2,0],
                [0,4]])
mu = 2
L = 4
con = 2

# %%
eta = 0.25

# %%
norms = []
x = [3, 3]
for i in range(50):
    grad = np.array([2 * x[0], 4 * x[1]])
    x = x - eta * grad
    norms.append(np.linalg.norm(grad))

iterations = np.arange(50)

# %%
plt.semilogy(iterations, norms)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
eta = 1
norms = []
x = [3, 3]
for i in range(50):
    grad = np.array([2 * x[0], 4 * x[1]])
    x = x - eta * grad
    norms.append(np.linalg.norm(grad))

iterations = np.arange(50)
# Out:
# C:\Users\leo\AppData\Local\Temp\ipykernel_23528\1310881193.py:5: RuntimeWarning: overflow encountered in scalar multiply
#   grad = np.array([2 * x[0], 4 * x[1]])

# %%
plt.semilogy(iterations, norms)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
