# %%
import numpy as np

a = np.array([1, 2, 3], dtype = 'int8')
a
# Out:
# array([1, 2, 3], dtype=int8)

# %%
b = np.array([[9.0, 8.0, 7.0], [6.0, 5.0, 4.0]], dtype = 'float16')
b
# Out:
# array([[9., 8., 7.],
#        [6., 5., 4.]], dtype=float16)

# %%
#getting dimensions (ndim)
a.ndim
# Out:
# 1

# %%
b.ndim
# Out:
# 2

# %%
#Get Shape
a.shape
# Out:
# (3,)

# %%
b.shape
# Out:
# (2, 3)

# %%
#Get type
a.dtype
# Out:
# dtype('int8')

# %%
b.dtype
# Out:
# dtype('float16')

# %%
#Get Size
a.itemsize
# Out:
# 1

# %%
# Get total size
a.size * a.itemsize
# Out:
# 3

# %%
#Alternative way is 
a.nbytes
# Out:
# 3
